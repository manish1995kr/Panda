# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({"Gender":['m','f','f','m','m','f','m','f'],"height":[156,148,196,185,180,175,182,183],"weight":[60,65,63,64,58,59,63,58]})
df
# Out:
#   Gender  height  weight
# 0      m     156      60
# 1      f     148      65
# 2      f     196      63
# 3      m     185      64
# 4      m     180      58
# 5      f     175      59
# 6      m     182      63
# 7      f     183      58

# %%
df.groupby("Gender")["weight"].max()
# Out:
# Gender
# f    65
# m    64
# Name: weight, dtype: int64

# %%
df.groupby("Gender")["weight"].mean()
# Out:
# Gender
# f    61.25
# m    61.25
# Name: weight, dtype: float64

# %%
df.groupby("Gender")["weight"].agg(["mean","min","max","std"])
# Out:
#          mean  min  max       std
# Gender
# f       61.25   58   65  3.304038
# m       61.25   58   64  2.753785

# %%
df.groupby("Gender")["weight",'height'].agg(["mean","min","max","std"])
# Out:
# <ipython-input-7-fbd9c70f9ab4>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby("Gender")["weight",'height'].agg(["mean","min","max","std"])
#        weight                    height
#          mean min max       std    mean  min  max        std
# Gender
# f       61.25  58  65  3.304038  175.50  148  196  20.273135
# m       61.25  58  64  2.753785  175.75  156  185  13.326040

# %% [markdown]
# # Datetime Operations

# %%
pip install pandas-datareader
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas_datareader as pdr

# %%
df = pdr.get_data_yahoo("TSLA",start = "2022-01-01",end = "2022-03-20")

# %%
df
# Out:
#                    High          Low         Open        Close    Volume  \
# Date
# 2021-12-31  1082.000000  1054.589966  1073.439941  1056.780029  13577900
# 2022-01-03  1201.069946  1136.040039  1147.750000  1199.780029  34643800
# 2022-01-04  1208.000000  1123.050049  1189.550049  1149.589966  33416100
# 2022-01-05  1170.339966  1081.010010  1146.650024  1088.119995  26706600
# 2022-01-06  1088.000000  1020.500000  1077.000000  1064.699951  30112200
# 2022-01-07  1080.930054  1010.000000  1080.369995  1026.959961  27919000
# 2022-01-10  1059.099976   980.000000  1000.000000  1058.119995  30605000
# 2022-01-11  1075.849976  1038.819946  1053.670044  1064.400024  22021100
# 2022-01-12  1114.839966  1072.589966  1078.849976  1106.219971  27913000
# 2022-01-13  1115.599976  1026.540039  1109.069946  1031.560059  32403300
# 2022-01-14  1052.000000  1013.380005  1019.880005  1049.609985  24246600
# 2022-01-18  1070.790039  1016.059998  1026.609985  1030.510010  22247800
# ...

# %%
df.index
# Out:
# DatetimeIndex(['2021-12-31', '2022-01-03', '2022-01-04', '2022-01-05',
#                '2022-01-06', '2022-01-07', '2022-01-10', '2022-01-11',
#                '2022-01-12', '2022-01-13', '2022-01-14', '2022-01-18',
#                '2022-01-19', '2022-01-20', '2022-01-21', '2022-01-24',
#                '2022-01-25', '2022-01-26', '2022-01-27', '2022-01-28',
#                '2022-01-31', '2022-02-01', '2022-02-02', '2022-02-03',
#                '2022-02-04', '2022-02-07', '2022-02-08', '2022-02-09',
#                '2022-02-10', '2022-02-11', '2022-02-14', '2022-02-15',
#                '2022-02-16', '2022-02-17', '2022-02-18', '2022-02-22',
#                '2022-02-23', '2022-02-24', '2022-02-25', '2022-02-28',
#                '2022-03-01', '2022-03-02', '2022-03-03', '2022-03-04',
#                '2022-03-07', '2022-03-08', '2022-03-09', '2022-03-10',
#                '2022-03-11', '2022-03-14', '2022-03-15', '2022-03-16',
# ...

# %%
df["High"]
# Out:
# Date
# 2021-12-31    1082.000000
# 2022-01-03    1201.069946
# 2022-01-04    1208.000000
# 2022-01-05    1170.339966
# 2022-01-06    1088.000000
# 2022-01-07    1080.930054
# 2022-01-10    1059.099976
# 2022-01-11    1075.849976
# 2022-01-12    1114.839966
# 2022-01-13    1115.599976
# 2022-01-14    1052.000000
# 2022-01-18    1070.790039
# 2022-01-19    1054.670044
# 2022-01-20    1041.660034
# 2022-01-21    1004.549988
# 2022-01-24     933.510010
# 2022-01-25     951.260010
# 2022-01-26     987.690002
# 2022-01-27     935.390015
# 2022-01-28     857.500000
# 2022-01-31     937.989990
# 2022-02-01     943.700012
# 2022-02-02     931.500000
# 2022-02-03     937.000000
# 2022-02-04     936.500000
# 2022-02-07     947.770020
# 2022-02-08     926.289978
# 2022-02-09     946.270020
# 2022-02-10     943.809998
# 2022-02-11     915.960022
# 2022-02-14     898.880005
# 2022-02-15     923.000000
# 2022-02-16     926.429993
# 2022-02-17     918.500000
# 2022-02-18     886.869995
# ...

# %%
df["High"].max()
# Out:
# 1208.0

# %%
df["Low"].max()
# Out:
# 1136.0400390625

# %%
df["High"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df[df["High"]==1208]
# Out:
#               High          Low         Open        Close    Volume  \
# Date
# 2022-01-04  1208.0  1123.050049  1189.550049  1149.589966  33416100
#
#               Adj Close
# Date
# 2022-01-04  1149.589966

# %%
data = pd.read_csv("C:\\Users\\Manish\\Downloads\\catalog.csv")
data
# Out:
#         id     date   time continent_code   country_name country_code  \
# 0       34   3/2/07  Night            NaN  United States           US
# 1       42  3/22/07    NaN            NaN  United States           US
# 2       56   4/6/07    NaN            NaN  United States           US
# 3       59  4/14/07    NaN            NaN         Canada           CA
# 4       61  4/15/07    NaN            NaN  United States           US
# ...    ...      ...    ...            ...            ...          ...
# 1688  7535  12/7/15    NaN            NaN  United States           US
# 1689  7537  2/22/16   0:00            NaN  United States           US
# 1690  7539  2/23/16    NaN            NaN  United States           US
# 1691  7540  2/26/16  21:06            NaN  United States           US
# 1692  7541   3/2/16   8:00            NaN  United States           US
#
#       state/province  population         city/town  distance  ...  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1693 entries, 0 to 1692
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    1693 non-null   int64
#  1   date                  1690 non-null   object
#  2   time                  629 non-null    object
#  3   continent_code        164 non-null    object
#  4   country_name          1693 non-null   object
#  5   country_code          1693 non-null   object
#  6   state/province        1692 non-null   object
#  7   population            1693 non-null   int64
#  8   city/town             1689 non-null   object
#  9   distance              1692 non-null   float64
#  10  location_description  551 non-null    object
#  11  latitude              1692 non-null   float64
#  12  longitude             1692 non-null   float64
#  13  geolocation           1692 non-null   object
#  14  hazard_type           1693 non-null   object
# ...

# %%
data.date.dtype
# Out:
# dtype('O')

# %%
data["date"].mode()
# Out:
# 0     5/3/10
# 1    9/12/13
# dtype: object

# %%
data["date"].fillna(data["date"].mode()[0],inplace = True)

# %%
data["date"].isna().sum()
# Out:
# 0

# %%
data["date"] = pd.to_datetime(data["date"])

# %%
data.date.dtype
# Out:
# dtype('<M8[ns]')

# %%
data.dtypes
# Out:
# id                               int64
# date                    datetime64[ns]
# time                            object
# continent_code                  object
# country_name                    object
# country_code                    object
# state/province                  object
# population                       int64
# city/town                       object
# distance                       float64
# location_description            object
# latitude                       float64
# longitude                      float64
# geolocation                     object
# hazard_type                     object
# landslide_type                  object
# landslide_size                  object
# trigger                         object
# storm_name                      object
# injuries                       float64
# fatalities                     float64
# source_name                     object
# source_link                     object
# dtype: object

# %%
data["date"]
# Out:
# 0      2007-03-02
# 1      2007-03-22
# 2      2007-04-06
# 3      2007-04-14
# 4      2007-04-15
#           ...
# 1688   2015-12-07
# 1689   2016-02-22
# 1690   2016-02-23
# 1691   2016-02-26
# 1692   2016-03-02
# Name: date, Length: 1693, dtype: datetime64[ns]

# %%
from datetime import datetime as dt

# %%
data["year"] = data.date.dt.year

# %%
data.head()
# Out:
#    id       date   time continent_code   country_name country_code  \
# 0  34 2007-03-02  Night            NaN  United States           US
# 1  42 2007-03-22    NaN            NaN  United States           US
# 2  56 2007-04-06    NaN            NaN  United States           US
# 3  59 2007-04-14    NaN            NaN         Canada           CA
# 4  61 2007-04-15    NaN            NaN  United States           US
#
#   state/province  population         city/town  distance  ... hazard_type  \
# 0       Virginia       16000       Cherry Hill   3.40765  ...   Landslide
# 1           Ohio       17288  New Philadelphia   3.33522  ...   Landslide
# 2   Pennsylvania       15930       Wilkinsburg   2.91977  ...   Landslide
# 3         Quebec       42786       Châteauguay   2.98682  ...   Landslide
# 4       Kentucky        6903         Pikeville   5.66542  ...   Landslide
#
#        landslide_type  landslide_size   trigger storm_name injuries  \
# ...

# %%
data.year
# Out:
# 0       2007
# 1       2007
# 2       2007
# 3       2007
# 4       2007
#         ...
# 1688    2015
# 1689    2016
# 1690    2016
# 1691    2016
# 1692    2016
# Name: year, Length: 1693, dtype: int64

# %%
data["month"] = data.date.dt.month

# %%
data.month
# Out:
# 0        3
# 1        3
# 2        4
# 3        4
# 4        4
#         ..
# 1688    12
# 1689     2
# 1690     2
# 1691     2
# 1692     3
# Name: month, Length: 1693, dtype: int64

# %%
data.head()
# Out:
#    id       date   time continent_code   country_name country_code  \
# 0  34 2007-03-02  Night            NaN  United States           US
# 1  42 2007-03-22    NaN            NaN  United States           US
# 2  56 2007-04-06    NaN            NaN  United States           US
# 3  59 2007-04-14    NaN            NaN         Canada           CA
# 4  61 2007-04-15    NaN            NaN  United States           US
#
#   state/province  population         city/town  distance  ...  \
# 0       Virginia       16000       Cherry Hill   3.40765  ...
# 1           Ohio       17288  New Philadelphia   3.33522  ...
# 2   Pennsylvania       15930       Wilkinsburg   2.91977  ...
# 3         Quebec       42786       Châteauguay   2.98682  ...
# 4       Kentucky        6903         Pikeville   5.66542  ...
#
#        landslide_type  landslide_size   trigger storm_name injuries  \
# 0           Landslide           Small      Rain        NaN      NaN
# ...

# %%
data.hazard_type.unique()
# Out:
# array(['Landslide'], dtype=object)

# %%
len(data.columns)
# Out:
# 25

# %%
data.year.unique()
# Out:
# array([2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016],
#       dtype=int64)

# %%
x = data.groupby(["country_name","year"])["hazard_type"].count()
x
# Out:
# country_name   year
# Barbados       2008      1
# Belize         2015      1
# Bermuda        2011      1
#                2014      1
# Brazil         2009      2
#                       ...
# United States  2015    140
#                2016     16
# Venezuela      2008      1
#                2010     15
#                2011      4
# Name: hazard_type, Length: 150, dtype: int64

# %%
x = pd.DataFrame(x)

# %%
x.reset_index(inplace = True)

# %%
x
# Out:
#       country_name  year  hazard_type
# 0         Barbados  2008            1
# 1           Belize  2015            1
# 2          Bermuda  2011            1
# 3          Bermuda  2014            1
# 4           Brazil  2009            2
# ..             ...   ...          ...
# 145  United States  2015          140
# 146  United States  2016           16
# 147      Venezuela  2008            1
# 148      Venezuela  2010           15
# 149      Venezuela  2011            4
#
# [150 rows x 3 columns]

# %%
x["country_name"].unique()
# Out:
# array(['Barbados', 'Belize', 'Bermuda', 'Brazil', 'Canada', 'Colombia',
#        'Costa Rica', 'Cuba', 'Dominica', 'Dominican Republic', 'Ecuador',
#        'El Salvador', 'Grenada', 'Guatemala', 'Haiti', 'Honduras',
#        'Jamaica', 'Mexico', 'Nicaragua', 'Panama', 'Peru', 'Puerto Rico',
#        'Saint Lucia', 'Saint Vincent and the Grenadines',
#        'Trinidad and Tobago', 'U.S. Virgin Islands', 'United States',
#        'Venezuela'], dtype=object)

# %%
data["landslide_size"].unique()
# Out:
# array(['Small', 'Large', 'Medium', 'Very_large', 'medium', 'large',
#        'small', nan], dtype=object)

# %%
data["landslide_size"] = data["landslide_size"].replace({"large":"Large","small":"Small","medium":"Medium"})

# %%
data.landslide_size.unique()
# Out:
# array(['Small', 'Large', 'Medium', 'Very_large', nan], dtype=object)

# %%
data.time.unique()
# Out:
# array(['Night', nan, '19:30:00', 'Early morning', '1:41:00', 'Afternoon',
#        '11:30:00', 'Morning', '23:25:00', '18:00:00', '22:00:00',
#        '17:36:00', 'Overnight', '16:30:00', '13:40:00', '15:00:00',
#        '7:00:00', '19:00:00', '22:00', '0:00:00', '12:00', '6:45:00',
#        '18:15:00', '2:00:00', 'Late morning', '23:30:00', '11:00:00',
#        '7:19:00', 'Evening', '21:00:00', '5:00:00', '10:00:00',
#        '17:00:00', '1:30:00', '12:00:00', '5:30:00', '6:00:00',
#        'Late evening', '8:00:00', '14:30:00', '15:45:00', '9:30:00',
#        '18:46:00', '2:30:00', '15:30:00', '13:45:00', '15:40:00',
#        '14:10:00', '4:30:00', '18:53:00', '11:45:00', 'Late night',
#        '23:00:00', '13:00:00', '3:00:00', '4:00:00', '20:00:00', '13:00',
#        '0:15:00', '0:30:00', '10:30:00', 'Before dawn', '9:00:00',
#        '7:30:00', '14:00:00', '1:00:00', '12:30:00', '21:30:00', '12:15',
#        '1:52:00', 'Late afternoon', '9:50:00', '5:45:00', '3:30:00',
# ...
